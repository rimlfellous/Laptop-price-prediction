# %%
# !pip install --upgrade scikit-learn

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error 
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
df = pd.read_csv('C:/Users/rim-1/Desktop/laptop/laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
#we can see that the Columns: Ram & Weight have data type of Object we will convert to numeric data type later in cleaning process.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
#we will delete the GB nad KG from ram and weight, and transform price from the current currency to MAD.

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')
df['Price'] = df['Price'] * 0.12
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight         Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   8565.441984
# 1        Intel HD Graphics 6000  macOS   1.34   5747.462784
# ...

# %%
#we convert Ram and WEIGHT to numerical type
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
#feature analysis

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Most of the laptop brands are Dell, lenovo and Hp

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# we can see that Razer laptops are more expensive than the other brands.

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#as we see Notebook laptop type is dominant in our dataset

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
#from above graph we can see that the higher the size of laptop screeen the higher the price of laptop.
#So size does matter :)

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
# Fetching touchscreen data from screenresolution column
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(3)
# Out:
#     Company            TypeName  Inches  \
# 975      HP            Notebook    15.6
# 216  Lenovo            Notebook    17.3
# 413    Acer  2 in 1 Convertible    13.3
#
#                               ScreenResolution                          Cpu  \
# 975                IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz
# 216                                   1600x900   Intel Core i5 7200U 2.5GHz
# 413  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
#
#      Ram                Memory                       Gpu       OpSys  Weight  \
# 975    8  128GB SSD +  1TB HDD      Nvidia GeForce 930MX  Windows 10    2.04
# 216    8               1TB HDD  Nvidia GeForce GTX 940MX       No OS    2.80
# 413    8             256GB SSD     Intel HD Graphics 520  Windows 10    1.60
#
#            Price  Touchscreen
# 975  6259.334400            0
# 216  3765.830400            0
# 413  5044.614336            1

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
#if Ips pannel is present in Screenresolution we store it in new column
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0    1
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Non IPs panel laptops are most in dataset

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Ips', ylabel='Price'>

# %%
#we can see that the price of laptops also depend on ips panel

# %%
#fetching x resolution & y resolution from the screen resolution column¶
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
df['X_res'] = new[0]
df['Y_res'] = new[1]
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 599     Dell         Workstation    15.6
# 156   Lenovo  2 in 1 Convertible    14.0
# 1211    Asus            Notebook    15.6
# 338     Asus            Notebook    15.6
# 1283    Asus            Notebook    15.6
#
#                                ScreenResolution  \
# 599             Full HD / Touchscreen 1920x1080
# 156   IPS Panel Full HD / Touchscreen 1920x1080
# 1211                          Full HD 1920x1080
# 338                                    1366x768
# 1283                                   1366x768
#
#                                        Cpu  Ram                Memory  \
# 599            Intel Core i7 7700HQ 2.8GHz    8             256GB SSD
# 156             Intel Core i3 7100U 2.4GHz    4             256GB SSD
# 1211           Intel Core i7 7700HQ 2.8GHz   16  128GB SSD +  1TB HDD
# 338   Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# ...

# %%
# Out:
#       Company            TypeName  Inches  \
# 1168       HP            Notebook    14.0
# 973   Toshiba            Notebook    14.0
# 783    Lenovo            Notebook    15.6
# 755    Lenovo  2 in 1 Convertible    13.3
# 511      Acer            Notebook    15.6
#
#                                 ScreenResolution  \
# 1168                                    1366x768
# 973                            Full HD 1920x1080
# 783                                     1366x768
# 755   IPS Panel Quad HD+ / Touchscreen 3200x1800
# 511                            Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 1168  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 973             Intel Core i5 6200U 2.3GHz    8           256GB SSD
# 783   Intel Celeron Quad Core N3710 1.6GHz    8             1TB HDD
# 755             Intel Core i5 6260U 1.8GHz    8           256GB SSD
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0
# 1        Intel HD Graphics 6000  macOS    1.34   5747.462784            0
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
#we can notice that the correlation is very weak with inches but somewhat important with resolutions
#for that we will create another variable to better analyse the corr

# %%
#we create a new column to store the pixels per inch 
#why? ---> Higher ppi values  indicate a higher resolution and sharper display.
#how? --> we calculate the diagonal resolution using the Pythagorean theorem then we divide it by the screen size
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#with this, we can conclude that the ppi has an important correlation now with the price

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#           Price  Touchscreen  Ips  X_res  Y_res         ppi
# 0   8565.441984            0    1   2560   1600  226.983005
# 1   5747.462784            0    0   1440    900  127.677940
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0
# 1        Intel HD Graphics 6000  macOS    1.34   5747.462784            0
# 2         Intel HD Graphics 620  No OS    1.86   3676.320000            0
# 3            AMD Radeon Pro 455  macOS    1.83  16223.440320            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37  11531.496960            0
#
#    Ips         ppi
# 0    1  226.983005
# 1    0  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#since the rest of the data in cpu doesnt interest us we will only use the first 3 words
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0
# 1        Intel HD Graphics 6000  macOS    1.34   5747.462784            0
# 2         Intel HD Graphics 620  No OS    1.86   3676.320000            0
# 3            AMD Radeon Pro 455  macOS    1.83  16223.440320            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37  11531.496960            0
#
#    Ips         ppi       Cpu Name
# 0    1  226.983005  Intel Core i5
# ...

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0
# 1        Intel HD Graphics 6000  macOS    1.34   5747.462784            0
# 2         Intel HD Graphics 620  No OS    1.86   3676.320000            0
# 3            AMD Radeon Pro 455  macOS    1.83  16223.440320            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37  11531.496960            0
#
#    Ips         ppi       Cpu Name
# 0    1  226.983005  Intel Core i5
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight         Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   8565.441984            0
# 1        Intel HD Graphics 6000  macOS    1.34   5747.462784            0
# 2         Intel HD Graphics 620  No OS    1.86   3676.320000            0
# 3            AMD Radeon Pro 455  macOS    1.83  16223.440320            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37  11531.496960            0
#
#    Ips         ppi       Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#our data has mostly intel core i7 brands

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#indeed intel core i7 means higher prices

# %%
#since we won't use these 2 columns, we drop them
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight         Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   8565.441984            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   5747.462784            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   3676.320000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  16223.440320            0    1  220.534624  Intel Core i7
# 4  macOS    1.37  11531.496960            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#the size of the ram does matter

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# in this section, we process the data in memory

#we convert 'Memory' column to string and remove decimal points
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
# Remove 'GB' and replace 'TB' with '000'
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
# then we Split 'Memory' column into two parts using the '+' sign
new = df["Memory"].str.split("+", n = 1, expand = True)


# the first part of the split
df["first"]= new[0]
df["first"]=df["first"].str.strip()
# the second part of the split
df["second"]= new[1]

#we create binary columns indicating the presence of different storage types in the first layer
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

#then remove non-digit characters from the 'first' column
df['first'] = df['first'].str.replace(r'\D', '')

# we fill missing values in the 'second' column with "0" since there are data with only one memory type
df["second"].fillna("0", inplace = True)

#we perform same op as the first layer 
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

#
df['second'] = df['second'].str.replace(r'\D', '')

# now we convert 'first' and 'second' columns to integers
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# we calculate the total capacity for each storage type based on layers and capacities
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

# lastly we drop intermediate columns that no longer will serve our prediction
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\rim-1\AppData\Local\Temp\ipykernel_16484\2426417626.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\rim-1\AppData\Local\Temp\ipykernel_16484\2426417626.py:37: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram               Memory                      Gpu  \
# 1214    Asus     Gaming   16  256 SSD +  1000 HDD  Nvidia GeForce GTX 1060
# 84      Acer   Notebook    4             1000 HDD            AMD Radeon R5
# 1065    Dell  Ultrabook    8              256 SSD    Intel HD Graphics 620
# 51      Acer   Notebook    8              256 SSD     Nvidia GeForce MX150
# 669     Acer   Notebook    4              128 SSD    Intel HD Graphics 520
#
#            OpSys  Weight       Price  Touchscreen  Ips         ppi  \
# 1214  Windows 10    2.90  12461.1264            0    0  127.335675
# 84    Windows 10    2.10   2525.4720            0    0  100.454670
# 1065  Windows 10    1.29   9321.8688            0    0  165.632118
# 51    Windows 10    2.20   5377.0176            0    1  141.211998
# 669        Linux    2.10   2634.1632            0    0  100.454670
#
#           Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# 1214  Intel Core i7  1000  256       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#           Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   8565.441984            0    1  226.983005  Intel Core i5    0  128
# 1   5747.462784            0    0  127.677940  Intel Core i5    0    0
# 2   3676.320000            0    0  141.211998  Intel Core i5    0  256
# 3  16223.440320            0    1  220.534624  Intel Core i7    0  512
# 4  11531.496960            0    1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# 1       0            128
# 2       0              0
# ...

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
#the hybrid and flash storage do not interest us anymore

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#           Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   8565.441984            0    1  226.983005  Intel Core i5    0  128
# 1   5747.462784            0    0  127.677940  Intel Core i5    0    0
# 2   3676.320000            0    0  141.211998  Intel Core i5    0  256
# 3  16223.440320            0    1  220.534624  Intel Core i7    0  512
# 4  11531.496960            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#           Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   8565.441984            0    1  226.983005  Intel Core i5    0  128
# 1   5747.462784            0    0  127.677940  Intel Core i5    0    0
# 2   3676.320000            0    0  141.211998  Intel Core i5    0  256
# 3  16223.440320            0    1  220.534624  Intel Core i7    0  512
# 4  11531.496960            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
#we only have one type ARM, not so important
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
#although Intel GPU are the most in dataset, the Nvidia is more expensive

# %%
df.drop(columns=['Gpu'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight         Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   8565.441984            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   5747.462784            0    0
# 2      HP   Notebook    8  No OS    1.86   3676.320000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  16223.440320            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  11531.496960            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
#we will define a function to take care of different OPS
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight         Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   8565.441984            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   5747.462784            0    0
# 2      HP   Notebook    8  No OS    1.86   3676.320000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  16223.440320            0    1
# 4   Apple  Ultrabook    8  macOS    1.37  11531.496960            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
#we notice that most the weight is scattered between 1 and 3 kgs, but we can't really decide how much the weight controls the price yet

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
#we see a positive correlation between the weight of a laptop and its price that suggests a weak positive relationship 
#let's visualize the entire correlation matrix and gain insights into the relationships between "Price" and other variables.

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#we already noticed a high var in the prices 
#let's normalize the price using log 
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
#we're done with the preprocessing and visualistaion, we can move on to Spliting the dataset and modeling.

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       9.055491
# 1       8.656514
# 2       8.209668
# 3       9.694212
# 4       9.352837
#           ...
# 1298    8.313636
# 1299    9.167851
# 1300    7.289019
# 1301    8.493865
# 1302    7.766094
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
#ridge regression


# Step 1: Column Transformation
# we used OneHotEncoder to encode categorical variables (columns 0, 1, 7, 10, 11).
# to avoid multicollinearity we used 'drop='first'' to drop the first category 


step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


# Step 2: Linear Regression Model
# Create a Linear Regression model as the second step in the pipeline.
step2 = Ridge(alpha=10)

#we combine the Column Transformation and Linear Regression into a Pipeline.
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])


# we fit the pipeline
pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031311809
# MAE 0.20926802242582954
# C:\Users\rim-1\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Random Forest

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8864606281112678
# MAE 0.15866709238473678

# %%
#Gradient Boost

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8809471206525361
# MAE 0.1596689610764187

# %%
#XgBoost

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771407583310806
# MAE 0.16262919865515396
# C:\Users\rim-1\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Stacking


# to improve predictive performance we ill be combining multiple models

from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

#we Create a StackingRegressor with multiple base estimators (Random Forest, Gradient Boosting, XGBoost).
# The final estimator is Ridge Regression.
step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\rim-1\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.878865393333623
# MAE 0.1666120234098556

# %%
#Exporting the Model

#we will sue the model pickle to  to serialize and savethe DataFrame df and the machine learning pipeline pipe, 
#to later be used to create the user interface with streamlit
import pickle

pickle.dump(df,open('C:/Users/rim-1/Desktop/laptop/df.pkl','wb'))
pickle.dump(pipe,open('C:/Users/rim-1/Desktop/laptop/pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight         Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   8565.441984            0    1
# 1      Apple           Ultrabook    8    1.34   5747.462784            0    0
# 2         HP            Notebook    8    1.86   3676.320000            0    0
# 3      Apple           Ultrabook   16    1.83  16223.440320            0    1
# 4      Apple           Ultrabook    8    1.37  11531.496960            0    1
# ...      ...                 ...  ...     ...           ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   4079.116800            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   9584.006400            1    1
# 1300  Lenovo            Notebook    2    1.50   1464.134400            0    0
# 1301      HP            Notebook    6    2.19   4884.710400            0    0
# 1302    Asus            Notebook    4    2.20   2359.238400            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...
